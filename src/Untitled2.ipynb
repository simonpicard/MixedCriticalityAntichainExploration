# %%
import pandas as pd

# %%
r = pd.read_csv("sporadic_result.csv")

# %%
r["res"] = r["res"].astype(int)

# %%
rm = r.groupby("u").mean()

# %%
import matplotlib.pyplot as plt

# %%
rm.plot(
# Out:
#       Unnamed: 0  res        n        time  nbt
# u
# 0.40         4.5  1.0   2205.3    4.140842  4.0
# 0.41        14.5  1.0    300.4    1.777570  4.0
# 0.42        24.5  1.0    935.6    2.811675  4.0
# 0.43        34.5  1.0    750.5    2.630092  4.0
# 0.44        44.5  1.0   6221.7    9.251200  4.0
# 0.45        54.5  1.0    570.8    2.013852  4.0
# 0.46        64.5  1.0   2771.6    4.163403  4.0
# 0.47        74.5  1.0   1128.4    2.802058  4.0
# 0.48        84.5  1.0   7698.6   11.140981  4.0
# 0.49        94.5  1.0   2141.3    4.483778  4.0
# 0.50       104.5  1.0   5225.1    9.180461  4.0
# 0.51       114.5  1.0   2181.8    5.023357  4.0
# 0.52       124.5  1.0    736.2    2.645851  4.0
# 0.53       134.5  1.0   1780.8    3.527344  4.0
# 0.54       144.5  1.0   1515.1    3.390717  4.0
# 0.55       154.5  1.0  33077.9   37.696198  4.0
# 0.56       164.5  1.0  54261.4   76.846386  4.0
# 0.57       174.5  1.0   3468.0    5.703080  4.0
# ...
